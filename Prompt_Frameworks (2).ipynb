# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.0.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.0.0-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.0.0

# %%
from groq import Groq
client = Groq(api_key="insert your api key ")

# %% [markdown]
# Function to call LLMs

# %%
def call_llm(messages, temperature=0.3):
    response = client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=messages,
        temperature=temperature
    )
    return response.choices[0].message.content.strip()

# %% [markdown]
# PERSONA PROMPT

# %%
PERSONA_PROMPT = """
You are an AI and ML expert with 10+ years of industry experience.
You mentor fresh graduates and interns. You consistently behave as a mentor,
explaining concepts from fundamentals to real-world applications in simple language.
Do not hallucinate facts and do not give excess data.Prefer accuracy over creativity
"""

messages = [
    {"role": "system", "content": PERSONA_PROMPT},
    {"role": "user", "content": "Explain Text preprocessing"}
]

print(call_llm(messages))
# Out:
# Text preprocessing is a crucial step in natural language processing (NLP) and machine learning (ML) pipelines. It involves cleaning, transforming, and preparing text data to make it suitable for modeling and analysis.
#
# **Why is text preprocessing necessary?**
#
# Text data can be noisy, unstructured, and inconsistent, which can negatively impact the performance of NLP and ML models. Text preprocessing helps to:
#
# 1. Remove irrelevant information
# 2. Reduce dimensionality
# 3. Improve data quality
# 4. Enhance model interpretability
#
# **Common text preprocessing techniques:**
#
# 1. **Tokenization**: breaking down text into individual words or tokens.
# 2. **Stopword removal**: removing common words like "the", "and", "a", etc. that do not add much value to the text.
# 3. **Stemming or Lemmatization**: reducing words to their base form (e.g., "running" becomes "run").
# 4. **Removing special characters and punctuation**: eliminating characters that do not add meaning to the text.
# 5. **Removing numbers and dates**: eliminating numerical values that may not be relevant to the analysis.
# 6. **Vectorization**: converting text data into numerical vectors that can be processed by ML algorithms.
#
# **Real-world applications:**
#
# 1. **Sentiment analysis**: text preprocessing helps to remove noise and irrelevant information, allowing models to focus on sentiment-bearing words.
# 2. **Text classification**: preprocessing techniques like tokenization and stopword removal help to improve the accuracy of text classification models.
# 3. **Information retrieval**: text preprocessing enables efficient searching and indexing of text data.
#
# **Best practices:**
#
# 1. **Use established libraries and tools**: utilize popular libraries like NLTK, spaCy, or scikit-learn for text preprocessing.
# 2. **Experiment with different techniques**: try out various preprocessing methods to find the best approach for your specific problem.
# 3. **Evaluate the impact of preprocessing**: assess the effect of preprocessing on your model's performance and adjust accordingly.
#
# By applying these text preprocessing techniques, you can improve the quality and consistency of your text data, leading to better performance and more accurate results in your NLP and ML projects.

# %% [markdown]
# ROOT PROMPT

# %%
ROOT_PROMPT = """
You are an AI mentor with 10+ years of industry experience.
Explain concepts step-by-step.
Prefer accuracy over creativity.
Avoid hallucinations.
"""
messages = [
    {"role": "system", "content": ROOT_PROMPT},
    {"role": "user", "content": "Explain Prompting"}
]

print(call_llm(messages))
# Out:
# Prompting is a technique used to interact with artificial intelligence (AI) models, particularly language models, to elicit specific responses or generate text based on a given input. Here's a step-by-step explanation of prompting:
#
# **What is a prompt?**
# A prompt is a piece of text or input that is used to initiate a conversation or generate a response from an AI model. It can be a question, a statement, a phrase, or even a few words.
#
# **Types of prompts:**
# There are several types of prompts, including:
#
# 1. **Open-ended prompts**: These prompts encourage the AI model to generate a response without any specific constraints or guidelines. Example: "Write a story about a character who discovers a hidden world."
# 2. **Closed-ended prompts**: These prompts require the AI model to generate a response that is more specific and concise. Example: "What is the capital of France?"
# 3. **Guided prompts**: These prompts provide more context and guidance for the AI model to generate a response. Example: "Write a poem about a summer day, using only words that start with the letter 's'."
#
# **How prompting works:**
# When you provide a prompt to an AI model, it uses the input to generate a response based on its training data and algorithms. The model analyzes the prompt, identifies the key concepts and context, and then generates a response that is relevant and coherent.
#
# **Key factors that influence prompting:**
# Several factors can influence the effectiveness of prompting, including:
#
# 1. **Prompt clarity**: The prompt should be clear and concise to help the AI model understand the context and generate a relevant response.
# 2. **Prompt specificity**: The prompt should be specific enough to guide the AI model towards generating a response that meets the desired outcome.
# 3. **Model capabilities**: The capabilities and limitations of the AI model can impact the quality and relevance of the generated response.
# 4. **Contextual understanding**: The AI model's ability to understand the context and nuances of the prompt can significantly influence the generated response.
#
# **Best practices for prompting:**
# To get the most out of prompting, follow these best practices:
#
# 1. **Be specific**: Provide clear and specific prompts that guide the AI model towards generating a relevant response.
# 2. **Use relevant context**: Provide relevant context and background information to help the AI model understand the prompt and generate a more accurate response.
# 3. **Test and refine**: Test your prompts and refine them based on the generated responses to achieve the desired outcome.
# 4. **Understand model limitations**: Be aware of the AI model's limitations and capabilities to set realistic expectations and avoid disappointment.
#
# By following these guidelines and best practices, you can effectively use prompting to interact with AI models and generate high-quality responses that meet your needs.

# %% [markdown]
# COGNITIVE VERIFIER PATTERN

# %%
messages = [
    {"role": "user", "content": """
Explain cognitive verifier pattern in prompt engineering.

Now verify your answer:
- Is it correct?
- Is anything missing?
- Improve the explanation if needed.
"""}
]

print(call_llm(messages))
# Out:
# The cognitive verifier pattern is a technique used in prompt engineering to improve the accuracy and reliability of language models by incorporating a verification step into the prompt. This pattern involves asking the model to not only generate a response but also to verify the correctness of that response.
#
# The typical structure of a cognitive verifier prompt includes:
#
# 1. **Initial Question**: The user asks the model a question or provides a prompt to generate a response.
# 2. **Response Generation**: The model generates a response based on the input prompt.
# 3. **Verification Prompt**: The user asks the model to verify the correctness of the generated response, often by asking a follow-up question or providing additional context.
# 4. **Verification Response**: The model generates a response to the verification prompt, indicating whether the initial response was correct or not.
#
# The cognitive verifier pattern serves several purposes:
#
# * **Error detection**: By asking the model to verify its own response, it can detect potential errors or inconsistencies in the generated text.
# * **Confidence assessment**: The verification step can provide an estimate of the model's confidence in its response, helping to identify areas where the model may be uncertain or lacking in knowledge.
# * **Knowledge graph updating**: The cognitive verifier pattern can help to update the model's knowledge graph by identifying and correcting errors, thereby improving the model's overall performance and accuracy.
#
# Verification of the answer:
#
# * **Is it correct?**: The explanation provided is correct, as it accurately describes the cognitive verifier pattern and its purpose in prompt engineering.
# * **Is anything missing?**: The explanation could be improved by providing more examples of how the cognitive verifier pattern can be applied in different contexts, such as question-answering, text classification, or dialogue systems.
# * **Improve the explanation if needed**: To improve the explanation, additional details could be provided on how to design effective verification prompts, such as using specific keywords or phrases to trigger the model's verification mechanism. Additionally, the explanation could benefit from more concrete examples of the cognitive verifier pattern in action, demonstrating its effectiveness in improving the accuracy and reliability of language models.
#
# Improved explanation:
#
# The cognitive verifier pattern is a powerful technique in prompt engineering that enables language models to reflect on their own responses and verify their correctness. By incorporating a verification step into the prompt, users can improve the accuracy and reliability of the model's output, detect potential errors, and assess the model's confidence in its responses. To apply the cognitive verifier pattern effectively, it is essential to design well-crafted verification prompts that trigger the model's verification mechanism, such as asking follow-up questions or providing additional context. By doing so, users can unlock the full potential of language models and develop more robust and trustworthy AI systems.

# %% [markdown]
# QUESTION REFINEMENT PATTERN

# %%
messages = [
    {"role": "user", "content": """User question: "Explain AI"

Refine this question into:
1. Beginner-friendly
2. Technical
3. Research-level
"""}
]

print(call_llm(messages))
# Out:
# Here are the refined questions:
#
# **1. Beginner-friendly:** "What is Artificial Intelligence (AI) and how does it work in simple terms?"
#
# This question is perfect for those who are new to the concept of AI and want to understand the basics. It invites an explanation that is easy to grasp and avoids technical jargon.
#
# **2. Technical:** "Can you explain the fundamental concepts and techniques of Artificial Intelligence, including machine learning, deep learning, and natural language processing?"
#
# This question is suitable for those with a technical background or interest in AI. It requires a more detailed explanation of the technical aspects of AI, including various algorithms, models, and applications.
#
# **3. Research-level:** "What are the current advancements and challenges in Artificial Intelligence research, particularly in areas such as explainability, transfer learning, and adversarial robustness, and how are they addressing the limitations of current AI systems?"
#
# This question is geared towards researchers, academics, or experts in the field of AI. It assumes a high level of knowledge and invites a discussion on the latest research trends, open problems, and potential solutions in AI. The answer would require a deep understanding of the current state of AI research and its future directions.

# %% [markdown]
# PROVIDING NEW INFORMATION AND ASK QUESTIONS

# %%
messages = [
    {"role": "user", "content": """
Explain CNN briefly.
Introduce one new concept related to CNN.
Ask 2 follow-up questions.
"""}
]

print(call_llm(messages))
# Out:
# **Brief Introduction to CNN:**
# A Convolutional Neural Network (CNN) is a type of deep learning model that is commonly used for image and video processing tasks. It consists of multiple layers, including convolutional layers, pooling layers, and fully connected layers, which work together to extract features from input data and make predictions.
#
# **New Concept:**
# One concept related to CNN is **Transfer Learning**, which involves using a pre-trained CNN model as a starting point for a new task. The pre-trained model has already learned to recognize general features from a large dataset, and by fine-tuning it on a smaller dataset, it can adapt to the new task with less training data and computational resources.
#
# **Follow-up Questions:**
# 1. How can transfer learning be applied to real-world problems, such as object detection or image classification, using pre-trained CNN models like VGG16 or ResNet50?
# 2. What are the limitations of using pre-trained CNN models for transfer learning, and how can they be addressed to improve the performance of the model on a specific task?

# %% [markdown]
# CHAIN OF THOUGHT

# %%
messages = [
    {"role": "user", "content": """
Explain TF-IDF in steps:
1. Explain Term Frequency
2. Explain Inverse Document Frequency
3. Combine both
"""}
]

print(call_llm(messages))
# Out:
# Here's an explanation of TF-IDF in steps:
#
# **Step 1: Term Frequency (TF)**
# Term Frequency is a measure of how often a word appears in a document. It's calculated by dividing the number of times a word appears in a document by the total number of words in the document.
#
# TF = (Number of times a word appears in a document) / (Total number of words in the document)
#
# For example, let's say we have a document with the following text: "The quick brown fox jumps over the lazy dog."
#
# * The word "the" appears twice, and there are 9 words in the document, so the TF for "the" would be: TF = 2/9 = 0.22
# * The word "fox" appears once, so the TF for "fox" would be: TF = 1/9 = 0.11
#
# The goal of TF is to give more weight to words that appear frequently in a document, as they are likely to be more important.
#
# **Step 2: Inverse Document Frequency (IDF)**
# Inverse Document Frequency is a measure of how rare a word is across a collection of documents. It's calculated by taking the logarithm of the total number of documents divided by the number of documents that contain a word.
#
# IDF = log(Total number of documents / Number of documents containing a word)
#
# For example, let's say we have a collection of 100 documents, and the word "the" appears in 90 of them, while the word "fox" appears in only 5 of them.
#
# * The IDF for "the" would be: IDF = log(100/90) = 0.05 (since "the" is a very common word)
# * The IDF for "fox" would be: IDF = log(100/5) = 2.30 (since "fox" is a relatively rare word)
#
# The goal of IDF is to give more weight to words that are rare across the collection of documents, as they are likely to be more distinctive and important.
#
# **Step 3: Combining TF and IDF (TF-IDF)**
# TF-IDF is calculated by multiplying the TF and IDF values for each word.
#
# TF-IDF = TF x IDF
#
# Using the examples from above:
#
# * For the word "the" in the document: TF-IDF = 0.22 x 0.05 = 0.011
# * For the word "fox" in the document: TF-IDF = 0.11 x 2.30 = 0.253
#
# As you can see, the TF-IDF value for "fox" is much higher than for "the", even though "the" appears more frequently in the document. This is because "fox" is a relatively rare word across the collection of documents, and therefore gets a higher IDF value.
#
# The TF-IDF value gives a sense of the importance of a word in a document, taking into account both its frequency in the document and its rarity across the collection of documents. This is useful for tasks such as text classification, information retrieval, and topic modeling.

# %% [markdown]
# TABULAR FORMAT

# %%
messages = [
    {"role": "user", "content": """
Compare different types of prompting frameworks.
Return output in a table, make the columns and rows neatly aligned:
Type | Description | Example Algorithm
"""}
]

print(call_llm(messages))
# Out:
# Here's a comparison of different types of prompting frameworks in a table format:
#
#
# | Type                  | Description                                                 | Example Algorithm                                      |
# | --------------------- | ----------------------------------------------------------- | ------------------------------------------------------- |
# | Zero-Shot Prompting    | No training data, relies on model's prior knowledge        | "Write a story about a character who learns to fly"    |
# | Few-Shot Prompting    | Limited training data, fine-tunes model for specific task   | "Given examples: 'cat', 'dog'; classify 'bird'"      |
# | Chain-of-Thought      | Encourages model to generate step-by-step reasoning process | "Solve this math problem: 2 + 2 = ?; show your work" |
# | Priming               | Provides context to influence model's output                | "Write a story in the style of Shakespeare: ..."      |
# | Gradient-Based        | Uses gradient descent to optimize prompt for specific task | "Maximize probability of generating 'yes' for input"  |
# | Reinforcement Learning| Trains model through trial and error with rewards/penalties | "Generate text; reward coherence, penalize inconsistency" |
# | Meta-Prompting        | Learns to generate effective prompts for downstream tasks   | "Generate a prompt to elicit a specific response from model" |
#
#
# Note that these categories are not mutually exclusive, and many prompting frameworks combine elements from multiple categories.

# %% [markdown]
# FILL IN THE BLANKS

# %%
messages = [
    {"role": "user", "content": """
Fill in the blanks:

TF-IDF stands for _____.
TF measures _____.
IDF measures _____.
TF_IDF measures _____.
"""}
]

print(call_llm(messages))
# Out:
# Here are the completed sentences:
#
# 1. TF-IDF stands for Term Frequency-Inverse Document Frequency.
# 2. TF measures the frequency of a term in a document.
# 3. IDF measures the rarity of a term across a collection of documents.
# 4. TF-IDF measures the importance of a term in a document based on its frequency and rarity across the entire collection.

# %% [markdown]
# ROAL-GOAL-CONTEXT

# %%
RGC_PROMPT = """
Role: You are a data science mentor.
Goal: Teach Bigram and Trigram clearly.
Context: Student knows Python but is new to NLP.
"""

messages = [
    {"role": "system", "content": RGC_PROMPT},
    {"role": "user", "content": "Explain Bigram and Trigram with example"}
]

print(call_llm(messages))
# Out:
# **Introduction to Bigram and Trigram**
# =====================================
#
# In Natural Language Processing (NLP), Bigram and Trigram are fundamental concepts used to analyze and understand the structure of language. They are used to extract patterns and relationships between words in a sentence or text.
#
# **What is a Bigram?**
# --------------------
#
# A Bigram is a sequence of two adjacent words in a sentence or text. It is used to analyze the co-occurrence of words and identify patterns in language.
#
# **Example of Bigram:**
# ----------------------
#
#  Sentence: "I love eating pizza"
#
#  Bigrams:
#
# * "I love"
# * "love eating"
# * "eating pizza"
#
# **What is a Trigram?**
# ---------------------
#
# A Trigram is a sequence of three adjacent words in a sentence or text. It is used to analyze the co-occurrence of words and identify more complex patterns in language.
#
# **Example of Trigram:**
# ----------------------
#
#  Sentence: "I love eating pizza"
#
#  Trigrams:
#
# * "I love eating"
# * "love eating pizza"
#
# **Python Code to Generate Bigram and Trigram:**
# ----------------------------------------------
#
# ```python
# import re
# from nltk.util import ngrams
#
# def generate_bigram_trigram(sentence):
#     # Tokenize the sentence into words
#     words = re.findall(r'\b\w+\b', sentence.lower())
#
#     # Generate Bigrams
#     bigrams = list(ngrams(words, 2))
#     print("Bigrams:", bigrams)
#
#     # Generate Trigrams
#     trigrams = list(ngrams(words, 3))
#     print("Trigrams:", trigrams)
#
# # Test the function
# sentence = "I love eating pizza"
# generate_bigram_trigram(sentence)
# ```
#
# This code uses the NLTK library to generate Bigrams and Trigrams from a given sentence. The `ngrams` function is used to generate sequences of n items from the list of words.
#
# **Output:**
# ----------
#
# ```
# Bigrams: [('i', 'love'), ('love', 'eating'), ('eating', 'pizza')]
# Trigrams: [('i', 'love', 'eating'), ('love', 'eating', 'pizza')]
# ```
#
# In this example, the Bigrams and Trigrams are generated from the sentence "I love eating pizza". The output shows the sequences of two and three adjacent words, respectively.

# %% [markdown]
# ZERO-SHOT PROMPTING

# %%
messages = [
    {"role": "user", "content": "Classify sentiment: 'The product is not of expected quality!'"}
]

print(call_llm(messages))
# Out:
# The sentiment of the statement "The product is not of expected quality!" is NEGATIVE. The use of the word "not" and the phrase "expected quality" implies that the product has failed to meet the user's expectations, indicating dissatisfaction. The tone is also somewhat emphatic, with the exclamation mark adding to the negative emphasis.

# %% [markdown]
# ONE-SHOT PROMPTING

# %%
messages = [
    {"role": "user", "content": """
Text: "I hate delays"
Sentiment: Negative

Text: "This movie is fantastic"
Sentiment:
"""}
]

print(call_llm(messages))
# Out:
# Positive

# %% [markdown]
# FEW_SHOTS PROMPTING

# %%
messages = [
    {"role": "user", "content": """
Text: "I like this product"
Sentiment: Positive

Text: "Worst experience"
Sentiment: Negative

Text: "It was okay"
Sentiment: Neutral

Text: " Not an amazing service"
Sentiment:
"""}
]

print(call_llm(messages))
# Out:
# Negative
#
# Although the text doesn't directly state a strongly negative opinion, the use of "not amazing" implies a somewhat negative sentiment, as it sets a high expectation (amazing) and then explicitly states that the service did not meet it.
