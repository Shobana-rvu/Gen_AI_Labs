# %%
# !pip install -U langgraph langchain langchain-groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.3/496.3 kB 15.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.8
#     Uninstalling langchain-core-1.2.8:
#       Successfully uninstalled langchain-core-1.2.8
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.0.7
#     Uninstalling langgraph-1.0.7:
#       Successfully uninstalled langgraph-1.0.7
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.2.8
#     Uninstalling langchain-1.2.8:
#       Successfully uninstalled langchain-1.2.8
# ...

# %%
# !pip install -U langgraph langchain langchain-groq groq

# %%
import os
os.environ["GROQ_API_KEY"] = "your_api_key"

# %%
from typing import TypedDict
from langgraph.graph import StateGraph
from langchain_groq import ChatGroq

# ✅ Define state
class ChatState(TypedDict):
    message: str
    response: str

# ✅ Use a currently active Groq model
llm = ChatGroq(model="llama-3.1-8b-instant")

# ✅ Define node
def chatbot_node(state: ChatState):
    reply = llm.invoke(state["message"])
    return {"response": reply.content}

# ✅ Create graph
workflow = StateGraph(ChatState)
workflow.add_node("chatbot", chatbot_node)
workflow.set_entry_point("chatbot")

# ✅ Compile
app = workflow.compile()

print("Graph compiled successfully!")
# Out:
# Graph compiled successfully!

# %%
result = app.invoke({"message": "Explain LangGraph in simple words"})
print(result["response"])
# Out:
# **LangGraph: A Tool for Analyzing Language**
#
# LangGraph is a software tool designed to analyze and visualize the structure of languages. It's a powerful tool that helps researchers and linguists understand the complexities of human language.
#
# **Key Features:**
#
# 1. **Dependency Parsing**: LangGraph can break down sentences into their constituent parts, showing how words relate to each other in terms of grammar and syntax.
# 2. **Syntax Analysis**: The tool analyzes the structure of sentences, identifying relationships between words, phrases, and clauses.
# 3. **Visualization**: LangGraph creates interactive visualizations of sentence structures, making it easier to understand complex linguistic relationships.
# 4. **Corpus Analysis**: The tool can analyze large collections of text, providing insights into language usage and trends.
#
# **How LangGraph Works:**
#
# ...
